# %% [markdown]
# #### Chroma
# Chroma is a AI-native open-source vector database focused on developer productivity and happiness. Chroma is licensed under Apache 2.0.
#
#
# given below is exmaple of all vectorstore from langchains supported
# https://python.langchain.com/v0.2/docs/integrations/vectorstores/

# %%
## building a sample vectordb
from langchain_chroma import Chroma
from langchain_community.document_loaders import TextLoader
from langchain_community.embeddings import OllamaEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
loader = TextLoader("speech.txt")
data = loader.load()
data
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='The world must be made safe for democracy. Its peace must be planted upon the tested foundations of political liberty. We have no selfish ends to serve. We desire no conquest, no dominion. We seek no indemnities for ourselves, no material compensation for the sacrifices we shall freely make. We are but one of the champions of the rights of mankind. We shall be satisfied when those rights have been made as secure as the faith and the freedom of nations can make them.\n\nJust because we fight without rancor and without selfish object, seeking nothing for ourselves but what we shall wish to share with all free peoples, we shall, I feel confident, conduct our operations as belligerents without passion and ourselves observe with proud punctilio the principles of right and of fair play we profess to be fighting for.\n\n…\n\nIt will be all the easier for us to conduct ourselves as belligerents in a high spirit of right and fairness because we act without animus, not in enmity toward a people or with the desire to bring any injury or disadvantage upon them, but only in armed opposition to an irresponsible government which has thrown aside all considerations of humanity and of right and is running amuck. We are, let me say again, the sincere friends of the German people, and shall desire nothing so much as the early reestablishment of intimate relations of mutual advantage between us—however hard it may be for them, for the time being, to believe that this is spoken from our hearts.\n\nWe have borne with their present government through all these bitter months because of that friendship—exercising a patience and forbearance which would otherwise have been impossible. We shall, happily, still have an opportunity to prove that friendship in our daily attitude and actions toward the millions of men and women of German birth and native sympathy who live among us and share our life, and we shall be proud to prove it toward all who are in fact loyal to their neighbors and to the government in the hour of test. They are, most of them, as true and loyal Americans as if they had never known any other fealty or allegiance. They will be prompt to stand with us in rebuking and restraining the few who may be of a different mind and purpose. If there should be disloyalty, it will be dealt with with a firm hand of stern repression; but, if it lifts its head at all, it will lift it only here and there and without countenance except from a lawless and malignant few.\n\nIt is a distressing and oppressive duty, gentlemen of the Congress, which I have performed in thus addressing you. There are, it may be, many months of fiery trial and sacrifice ahead of us. It is a fearful thing to lead this great peaceful people into war, into the most terrible and disastrous of all wars, civilization itself seeming to be in the balance. But the right is more precious than peace, and we shall fight for the things which we have always carried nearest our hearts—for democracy, for the right of those who submit to authority to have a voice in their own governments, for the rights and liberties of small nations, for a universal dominion of right by such a concert of free peoples as shall bring peace and safety to all nations and make the world itself at last free.\n\nTo such a task we can dedicate our lives and our fortunes, everything that we are and everything that we have, with the pride of those who know that the day has come when America is privileged to spend her blood and her might for the principles that gave her birth and happiness and the peace which she has treasured. God helping her, she can do no other.')]

# %%
# Split
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=0)
splits = text_splitter.split_documents(data)

# %%
embedding=OllamaEmbeddings()
vectordb=Chroma.from_documents(documents=splits,embedding=embedding)
vectordb
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7700\3457754910.py:1: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaEmbeddings``.
#   embedding=OllamaEmbeddings()

# %%
## query it
query = "What does the speaker believe is the main reason the United States should enter the war?"
docs = vectordb.similarity_search(query)
docs[0].page_content
# Out:
# 'To such a task we can dedicate our lives and our fortunes, everything that we are and everything that we have, with the pride of those who know that the day has come when America is privileged to spend her blood and her might for the principles that gave her birth and happiness and the peace which she has treasured. God helping her, she can do no other.'

# %%
docs
# Out:
# [Document(id='188bb0c2-4a07-4995-aaf3-bb33d2c5f3bb', metadata={'source': 'speech.txt'}, page_content='To such a task we can dedicate our lives and our fortunes, everything that we are and everything that we have, with the pride of those who know that the day has come when America is privileged to spend her blood and her might for the principles that gave her birth and happiness and the peace which she has treasured. God helping her, she can do no other.'),
#  Document(id='b0aac4c7-8e97-44ef-91d7-5b308235b04a', metadata={'source': 'speech.txt'}, page_content='The world must be made safe for democracy. Its peace must be planted upon the tested foundations of political liberty. We have no selfish ends to serve. We desire no conquest, no dominion. We seek no indemnities for ourselves, no material compensation for the sacrifices we shall freely make. We are but one of the champions of the rights of mankind. We shall be satisfied when those rights have been made as secure as the faith and the freedom of nations can make them.'),
#  Document(id='0e7eaa15-b0cb-42ce-aef4-9d641697846e', metadata={'source': 'speech.txt'}, page_content='government in the hour of test. They are, most of them, as true and loyal Americans as if they had never known any other fealty or allegiance. They will be prompt to stand with us in rebuking and restraining the few who may be of a different mind and purpose. If there should be disloyalty, it will be dealt with with a firm hand of stern repression; but, if it lifts its head at all, it will lift it only here and there and without countenance except from a lawless and malignant few.'),
#  Document(id='ffb76a68-42ee-4072-9f97-f7a55af3a753', metadata={'source': 'speech.txt'}, page_content='Just because we fight without rancor and without selfish object, seeking nothing for ourselves but what we shall wish to share with all free peoples, we shall, I feel confident, conduct our operations as belligerents without passion and ourselves observe with proud punctilio the principles of right and of fair play we profess to be fighting for.\n\n…')]

# %%
## Saving to the disk
vectordb=Chroma.from_documents(documents=splits,embedding=embedding,persist_directory="./chroma_db")

# %%
# load from disk
db2 = Chroma(persist_directory="./chroma_db", embedding_function=embedding)
docs=db2.similarity_search(query)
print(docs[0].page_content)
# Out:
# To such a task we can dedicate our lives and our fortunes, everything that we are and everything that we have, with the pride of those who know that the day has come when America is privileged to spend her blood and her might for the principles that gave her birth and happiness and the peace which she has treasured. God helping her, she can do no other.

# %%
## similarity Search With Score
docs = vectordb.similarity_search_with_score(query)
docs
# Out:
# [(Document(id='ad628166-32ba-46d0-8548-a6365b4b59da', metadata={'source': 'speech.txt'}, page_content='To such a task we can dedicate our lives and our fortunes, everything that we are and everything that we have, with the pride of those who know that the day has come when America is privileged to spend her blood and her might for the principles that gave her birth and happiness and the peace which she has treasured. God helping her, she can do no other.'),
#   15518.755859375),
#  (Document(id='4074de7d-9262-4b61-b16e-74be12d4a029', metadata={'source': 'speech.txt'}, page_content='To such a task we can dedicate our lives and our fortunes, everything that we are and everything that we have, with the pride of those who know that the day has come when America is privileged to spend her blood and her might for the principles that gave her birth and happiness and the peace which she has treasured. God helping her, she can do no other.'),
#   15752.6689453125),
#  (Document(id='11cf71bd-cbb8-4d2d-96ca-cd7cad1e8b42', metadata={'source': 'speech.txt'}, page_content='The world must be made safe for democracy. Its peace must be planted upon the tested foundations of political liberty. We have no selfish ends to serve. We desire no conquest, no dominion. We seek no indemnities for ourselves, no material compensation for the sacrifices we shall freely make. We are but one of the champions of the rights of mankind. We shall be satisfied when those rights have been made as secure as the faith and the freedom of nations can make them.'),
#   18115.75),
#  (Document(id='c7d81511-581a-4e94-9089-228615608626', metadata={'source': 'speech.txt'}, page_content='The world must be made safe for democracy. Its peace must be planted upon the tested foundations of political liberty. We have no selfish ends to serve. We desire no conquest, no dominion. We seek no indemnities for ourselves, no material compensation for the sacrifices we shall freely make. We are but one of the champions of the rights of mankind. We shall be satisfied when those rights have been made as secure as the faith and the freedom of nations can make them.'),
#   18201.81640625)]

# %%
### Retriever option
retriever=vectordb.as_retriever()
retriever.invoke(query)[0].page_content
# Out:
# 'To such a task we can dedicate our lives and our fortunes, everything that we are and everything that we have, with the pride of those who know that the day has come when America is privileged to spend her blood and her might for the principles that gave her birth and happiness and the peace which she has treasured. God helping her, she can do no other.'

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: langchain in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from -r requirements.txt (line 1)) (0.3.26)
# Requirement already satisfied: python-dotenv in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from -r requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: ipykernel in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from -r requirements.txt (line 3)) (6.29.5)
# Requirement already satisfied: langchain-community in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from -r requirements.txt (line 4)) (0.3.27)
# Requirement already satisfied: pypdf in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from -r requirements.txt (line 5)) (5.7.0)
# Requirement already satisfied: bs4 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from -r requirements.txt (line 6)) (0.0.2)
# Requirement already satisfied: arxiv in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from -r requirements.txt (line 7)) (2.2.0)
# Requirement already satisfied: pymupdf in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from -r requirements.txt (line 8)) (1.26.3)
# Requirement already satisfied: wikipedia in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from -r requirements.txt (line 9)) (1.4.0)
# Requirement already satisfied: langchain-text-splitters in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from -r requirements.txt (line 10)) (0.3.8)
# Requirement already satisfied: langchain-openai in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from -r requirements.txt (line 11)) (0.3.27)
# Requirement already satisfied: chromadb in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from -r requirements.txt (line 12)) (1.0.15)
# Requirement already satisfied: sentence_transformers in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from -r requirements.txt (line 13)) (5.0.0)
# Requirement already satisfied: langchain_huggingface in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from -r requirements.txt (line 14)) (0.3.0)
# Requirement already satisfied: faiss-cpu in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from -r requirements.txt (line 15)) (1.11.0)
# Requirement already satisfied: langchain_chroma in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from -r requirements.txt (line 16)) (0.2.4)
# Requirement already satisfied: duckdb in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from -r requirements.txt (line 17)) (1.3.1)
# Requirement already satisfied: pandas in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from -r requirements.txt (line 18)) (2.3.0)
# Requirement already satisfied: openai in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from -r requirements.txt (line 19)) (1.93.0)
# Requirement already satisfied: langchain-groq in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from -r requirements.txt (line 20)) (0.3.5)
# Requirement already satisfied: duckduckgo_search==5.3.1b1 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from -r requirements.txt (line 21)) (5.3.1b1)
# Requirement already satisfied: mysql-connector-python in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from -r requirements.txt (line 25)) (9.3.0)
# Requirement already satisfied: SQLAlchemy in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from -r requirements.txt (line 26)) (2.0.41)
# Collecting validators==0.28.1 (from -r requirements.txt (line 27))
#   Downloading validators-0.28.1-py3-none-any.whl.metadata (3.6 kB)
# Collecting youtube_transcript_api (from -r requirements.txt (line 28))
#   Downloading youtube_transcript_api-1.1.1-py3-none-any.whl.metadata (23 kB)
# Collecting unstructured (from -r requirements.txt (line 29))
#   Downloading unstructured-0.18.3-py3-none-any.whl.metadata (24 kB)
# Collecting pytube (from -r requirements.txt (line 30))
#   Downloading pytube-15.0.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting numexpr (from -r requirements.txt (line 31))
#   Downloading numexpr-2.11.0-cp310-cp310-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: huggingface_hub in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from -r requirements.txt (line 32)) (0.33.2)
# Requirement already satisfied: click>=8.1.7 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from duckduckgo_search==5.3.1b1->-r requirements.txt (line 21)) (8.2.1)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from httpx[brotli,http2,socks]>=0.27.0->duckduckgo_search==5.3.1b1->-r requirements.txt (line 21)) (0.28.1)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from langchain->-r requirements.txt (line 1)) (0.3.68)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from langchain->-r requirements.txt (line 1)) (0.4.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from langchain->-r requirements.txt (line 1)) (2.11.7)
# Requirement already satisfied: requests<3,>=2 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from langchain->-r requirements.txt (line 1)) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from langchain->-r requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from langchain->-r requirements.txt (line 1)) (4.0.3)
# Requirement already satisfied: greenlet>=1 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from SQLAlchemy->-r requirements.txt (line 26)) (3.2.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from SQLAlchemy->-r requirements.txt (line 26)) (4.14.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain->-r requirements.txt (line 1)) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain->-r requirements.txt (line 1)) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r requirements.txt (line 1)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from requests<3,>=2->langchain->-r requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from requests<3,>=2->langchain->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from requests<3,>=2->langchain->-r requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from requests<3,>=2->langchain->-r requirements.txt (line 1)) (2025.6.15)
# Requirement already satisfied: comm>=0.1.1 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from ipykernel->-r requirements.txt (line 3)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from ipykernel->-r requirements.txt (line 3)) (1.8.14)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from ipykernel->-r requirements.txt (line 3)) (8.37.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from ipykernel->-r requirements.txt (line 3)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from ipykernel->-r requirements.txt (line 3)) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from ipykernel->-r requirements.txt (line 3)) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from ipykernel->-r requirements.txt (line 3)) (1.6.0)
# Requirement already satisfied: psutil in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from ipykernel->-r requirements.txt (line 3)) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from ipykernel->-r requirements.txt (line 3)) (27.0.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from ipykernel->-r requirements.txt (line 3)) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from ipykernel->-r requirements.txt (line 3)) (5.14.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from langchain-community->-r requirements.txt (line 4)) (3.12.13)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from langchain-community->-r requirements.txt (line 4)) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from langchain-community->-r requirements.txt (line 4)) (2.10.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from langchain-community->-r requirements.txt (line 4)) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from langchain-community->-r requirements.txt (line 4)) (2.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 4)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 4)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 4)) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 4)) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 4)) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 4)) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->-r requirements.txt (line 4)) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->-r requirements.txt (line 4)) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community->-r requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from bs4->-r requirements.txt (line 6)) (4.13.4)
# Requirement already satisfied: feedparser~=6.0.10 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from arxiv->-r requirements.txt (line 7)) (6.0.11)
# Requirement already satisfied: sgmllib3k in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from feedparser~=6.0.10->arxiv->-r requirements.txt (line 7)) (1.0.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from langchain-openai->-r requirements.txt (line 11)) (0.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from openai->-r requirements.txt (line 19)) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from openai->-r requirements.txt (line 19)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from openai->-r requirements.txt (line 19)) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from openai->-r requirements.txt (line 19)) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from openai->-r requirements.txt (line 19)) (4.67.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 19)) (1.3.0)
# Requirement already satisfied: httpcore==1.* in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from httpx>=0.27.0->httpx[brotli,http2,socks]>=0.27.0->duckduckgo_search==5.3.1b1->-r requirements.txt (line 21)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->httpx[brotli,http2,socks]>=0.27.0->duckduckgo_search==5.3.1b1->-r requirements.txt (line 21)) (0.16.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai->-r requirements.txt (line 11)) (2024.11.6)
# Requirement already satisfied: build>=1.0.3 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from chromadb->-r requirements.txt (line 12)) (1.2.2.post1)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from chromadb->-r requirements.txt (line 12)) (1.4.1)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 12)) (0.35.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from chromadb->-r requirements.txt (line 12)) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from chromadb->-r requirements.txt (line 12)) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from chromadb->-r requirements.txt (line 12)) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from chromadb->-r requirements.txt (line 12)) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from chromadb->-r requirements.txt (line 12)) (1.34.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from chromadb->-r requirements.txt (line 12)) (0.21.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from chromadb->-r requirements.txt (line 12)) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from chromadb->-r requirements.txt (line 12)) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from chromadb->-r requirements.txt (line 12)) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from chromadb->-r requirements.txt (line 12)) (1.73.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from chromadb->-r requirements.txt (line 12)) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from chromadb->-r requirements.txt (line 12)) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from chromadb->-r requirements.txt (line 12)) (33.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from chromadb->-r requirements.txt (line 12)) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from chromadb->-r requirements.txt (line 12)) (3.10.18)
# Requirement already satisfied: rich>=10.11.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from chromadb->-r requirements.txt (line 12)) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from chromadb->-r requirements.txt (line 12)) (4.24.0)
# Requirement already satisfied: six>=1.5 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb->-r requirements.txt (line 12)) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb->-r requirements.txt (line 12)) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb->-r requirements.txt (line 12)) (2.2.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from sentence_transformers->-r requirements.txt (line 13)) (4.53.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from sentence_transformers->-r requirements.txt (line 13)) (2.7.1)
# Requirement already satisfied: scikit-learn in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from sentence_transformers->-r requirements.txt (line 13)) (1.7.0)
# Requirement already satisfied: scipy in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from sentence_transformers->-r requirements.txt (line 13)) (1.15.3)
# Requirement already satisfied: Pillow in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from sentence_transformers->-r requirements.txt (line 13)) (11.3.0)
# Requirement already satisfied: filelock in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers->-r requirements.txt (line 13)) (3.18.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers->-r requirements.txt (line 13)) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from huggingface_hub->-r requirements.txt (line 32)) (2025.5.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from pandas->-r requirements.txt (line 18)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from pandas->-r requirements.txt (line 18)) (2025.2)
# Requirement already satisfied: groq<1,>=0.29.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from langchain-groq->-r requirements.txt (line 20)) (0.29.0)
# Collecting defusedxml<0.8.0,>=0.7.1 (from youtube_transcript_api->-r requirements.txt (line 28))
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting chardet (from unstructured->-r requirements.txt (line 29))
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting filetype (from unstructured->-r requirements.txt (line 29))
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting python-magic (from unstructured->-r requirements.txt (line 29))
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting lxml (from unstructured->-r requirements.txt (line 29))
#   Downloading lxml-6.0.0-cp310-cp310-win_amd64.whl.metadata (6.8 kB)
# Collecting nltk (from unstructured->-r requirements.txt (line 29))
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting emoji (from unstructured->-r requirements.txt (line 29))
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting python-iso639 (from unstructured->-r requirements.txt (line 29))
#   Downloading python_iso639-2025.2.18-py3-none-any.whl.metadata (14 kB)
# Collecting langdetect (from unstructured->-r requirements.txt (line 29))
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      -------------------------------------- 981.5/981.5 kB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting rapidfuzz (from unstructured->-r requirements.txt (line 29))
#   Downloading rapidfuzz-3.13.0-cp310-cp310-win_amd64.whl.metadata (12 kB)
# Collecting unstructured-client (from unstructured->-r requirements.txt (line 29))
#   Downloading unstructured_client-0.38.1-py3-none-any.whl.metadata (21 kB)
# Collecting wrapt (from unstructured->-r requirements.txt (line 29))
#   Downloading wrapt-1.17.2-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Collecting python-oxmsg (from unstructured->-r requirements.txt (line 29))
#   Downloading python_oxmsg-0.0.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting html5lib (from unstructured->-r requirements.txt (line 29))
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: pyproject_hooks in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from build>=1.0.3->chromadb->-r requirements.txt (line 12)) (1.2.0)
# Requirement already satisfied: colorama in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from build>=1.0.3->chromadb->-r requirements.txt (line 12)) (0.4.6)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from build>=1.0.3->chromadb->-r requirements.txt (line 12)) (8.7.0)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from build>=1.0.3->chromadb->-r requirements.txt (line 12)) (2.2.1)
# Requirement already satisfied: socksio==1.* in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from httpx[brotli,http2,socks]>=0.27.0->duckduckgo_search==5.3.1b1->-r requirements.txt (line 21)) (1.0.0)
# Requirement already satisfied: brotli in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from httpx[brotli,http2,socks]>=0.27.0->duckduckgo_search==5.3.1b1->-r requirements.txt (line 21)) (1.1.0)
# Requirement already satisfied: h2<5,>=3 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from httpx[brotli,http2,socks]>=0.27.0->duckduckgo_search==5.3.1b1->-r requirements.txt (line 21)) (4.2.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.27.0->duckduckgo_search==5.3.1b1->-r requirements.txt (line 21)) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.27.0->duckduckgo_search==5.3.1b1->-r requirements.txt (line 21)) (4.1.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb->-r requirements.txt (line 12)) (3.23.0)
# Requirement already satisfied: decorator in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 3)) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 3)) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 3)) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 3)) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 3)) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r requirements.txt (line 3)) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r requirements.txt (line 3)) (0.8.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb->-r requirements.txt (line 12)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb->-r requirements.txt (line 12)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb->-r requirements.txt (line 12)) (0.26.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r requirements.txt (line 3)) (4.3.8)
# Requirement already satisfied: pywin32>=300 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r requirements.txt (line 3)) (310)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 12)) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 12)) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 12)) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 12)) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 12)) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r requirements.txt (line 12)) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r requirements.txt (line 12)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r requirements.txt (line 12)) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r requirements.txt (line 12)) (0.6.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from langsmith>=0.1.17->langchain->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from langsmith>=0.1.17->langchain->-r requirements.txt (line 1)) (0.23.0)
# Requirement already satisfied: coloredlogs in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 12)) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 12)) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 12)) (5.29.5)
# Requirement already satisfied: sympy in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 12)) (1.14.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 12)) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 12)) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 12)) (1.34.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb->-r requirements.txt (line 12)) (0.55b1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from rich>=10.11.0->chromadb->-r requirements.txt (line 12)) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb->-r requirements.txt (line 12)) (0.1.2)
# Requirement already satisfied: networkx in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from torch>=1.11.0->sentence_transformers->-r requirements.txt (line 13)) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from torch>=1.11.0->sentence_transformers->-r requirements.txt (line 13)) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 12)) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from typer>=0.9.0->chromadb->-r requirements.txt (line 12)) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 12)) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 12)) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 12)) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from beautifulsoup4->bs4->-r requirements.txt (line 6)) (2.7)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 12)) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 12)) (3.5.4)
# Collecting webencodings (from html5lib->unstructured->-r requirements.txt (line 29))
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence_transformers->-r requirements.txt (line 13)) (3.0.2)
# Requirement already satisfied: joblib in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from nltk->unstructured->-r requirements.txt (line 29)) (1.5.1)
# Collecting olefile (from python-oxmsg->unstructured->-r requirements.txt (line 29))
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from scikit-learn->sentence_transformers->-r requirements.txt (line 13)) (3.6.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 3)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\asus\desktop\gen-ai_from_scratch\langchain\venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 3)) (0.2.3)
# Collecting aiofiles>=24.1.0 (from unstructured-client->unstructured->-r requirements.txt (line 29))
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting cryptography>=3.1 (from unstructured-client->unstructured->-r requirements.txt (line 29))
#   Downloading cryptography-45.0.5-cp37-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting cffi>=1.14 (from cryptography>=3.1->unstructured-client->unstructured->-r requirements.txt (line 29))
#   Downloading cffi-1.17.1-cp310-cp310-win_amd64.whl.metadata (1.6 kB)
# Collecting pycparser (from cffi>=1.14->cryptography>=3.1->unstructured-client->unstructured->-r requirements.txt (line 29))
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Downloading validators-0.28.1-py3-none-any.whl (39 kB)
# Downloading youtube_transcript_api-1.1.1-py3-none-any.whl (485 kB)
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading unstructured-0.18.3-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------------------- ---------- 1.3/1.8 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 6.9 MB/s eta 0:00:00
# Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
# Downloading numexpr-2.11.0-cp310-cp310-win_amd64.whl (146 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ---------------------------------------- 0.0/590.6 kB ? eta -:--:--
#    ---------------------------------------- 590.6/590.6 kB 5.2 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Downloading lxml-6.0.0-cp310-cp310-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    --------------- ------------------------ 1.6/4.0 MB 7.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.9/4.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 8.0 MB/s eta 0:00:00
# Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Downloading python_iso639-2025.2.18-py3-none-any.whl (167 kB)
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading python_oxmsg-0.0.2-py3-none-any.whl (31 kB)
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
# Downloading rapidfuzz-3.13.0-cp310-cp310-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    -------------------------------- ------- 1.3/1.6 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 6.7 MB/s eta 0:00:00
# Downloading unstructured_client-0.38.1-py3-none-any.whl (212 kB)
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading cryptography-45.0.5-cp37-abi3-win_amd64.whl (3.4 MB)
#    ---------------------------------------- 0.0/3.4 MB ? eta -:--:--
#    ------------------ --------------------- 1.6/3.4 MB 9.3 MB/s eta 0:00:01
#    ------------------------------------- -- 3.1/3.4 MB 7.7 MB/s eta 0:00:01
#    ---------------------------------------- 3.4/3.4 MB 7.7 MB/s eta 0:00:00
# Downloading cffi-1.17.1-cp310-cp310-win_amd64.whl (181 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Downloading wrapt-1.17.2-cp310-cp310-win_amd64.whl (38 kB)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py): started
#   Building wheel for langdetect (setup.py): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993364 sha256=fd971176b995b1e5b3c926ae7ece6c775c3bb10efdcdda0b832e1e1f784f35a6
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\95\03\7d\59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# Installing collected packages: webencodings, filetype, wrapt, validators, rapidfuzz, pytube, python-magic, python-iso639, pycparser, olefile, numexpr, lxml, langdetect, html5lib, emoji, defusedxml, chardet, aiofiles, youtube_transcript_api, python-oxmsg, nltk, cffi, cryptography, unstructured-client, unstructured
#
#    - --------------------------------------  1/25 [filetype]
#    - --------------------------------------  1/25 [filetype]
#    --- ------------------------------------  2/25 [wrapt]
#    ---- -----------------------------------  3/25 [validators]
#    ---- -----------------------------------  3/25 [validators]
#    ------ ---------------------------------  4/25 [rapidfuzz]
#    ------ ---------------------------------  4/25 [rapidfuzz]
#    ------ ---------------------------------  4/25 [rapidfuzz]
#    ------ ---------------------------------  4/25 [rapidfuzz]
#    ------ ---------------------------------  4/25 [rapidfuzz]
#    -------- -------------------------------  5/25 [pytube]
#    -------- -------------------------------  5/25 [pytube]
#    -------- -------------------------------  5/25 [pytube]
#    ----------- ----------------------------  7/25 [python-iso639]
#    ------------ ---------------------------  8/25 [pycparser]
#    ------------ ---------------------------  8/25 [pycparser]
#    -------------- -------------------------  9/25 [olefile]
#    ---------------- ----------------------- 10/25 [numexpr]
#    ----------------- ---------------------- 11/25 [lxml]
#    ----------------- ---------------------- 11/25 [lxml]
#    ----------------- ---------------------- 11/25 [lxml]
#    ----------------- ---------------------- 11/25 [lxml]
#    ------------------- -------------------- 12/25 [langdetect]
#    ------------------- -------------------- 12/25 [langdetect]
#    -------------------- ------------------- 13/25 [html5lib]
#    -------------------- ------------------- 13/25 [html5lib]
#    -------------------- ------------------- 13/25 [html5lib]
#    -------------------- ------------------- 13/25 [html5lib]
#    -------------------- ------------------- 13/25 [html5lib]
#    ------------------------ --------------- 15/25 [defusedxml]
#    ------------------------ --------------- 15/25 [defusedxml]
#    ------------------------- -------------- 16/25 [chardet]
#    ------------------------- -------------- 16/25 [chardet]
#    ------------------------- -------------- 16/25 [chardet]
#    ------------------------- -------------- 16/25 [chardet]
#    ------------------------- -------------- 16/25 [chardet]
#    ------------------------- -------------- 16/25 [chardet]
#    ------------------------- -------------- 16/25 [chardet]
#    ------------------------- -------------- 16/25 [chardet]
#    --------------------------- ------------ 17/25 [aiofiles]
#    ---------------------------- ----------- 18/25 [youtube_transcript_api]
#    ---------------------------- ----------- 18/25 [youtube_transcript_api]
#    ------------------------------ --------- 19/25 [python-oxmsg]
#    ------------------------------ --------- 19/25 [python-oxmsg]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    -------------------------------- ------- 20/25 [nltk]
#    --------------------------------- ------ 21/25 [cffi]
#    --------------------------------- ------ 21/25 [cffi]
#    ----------------------------------- ---- 22/25 [cryptography]
#    ----------------------------------- ---- 22/25 [cryptography]
#    ----------------------------------- ---- 22/25 [cryptography]
#    ----------------------------------- ---- 22/25 [cryptography]
#    ----------------------------------- ---- 22/25 [cryptography]
#    ----------------------------------- ---- 22/25 [cryptography]
#    ----------------------------------- ---- 22/25 [cryptography]
#    ----------------------------------- ---- 22/25 [cryptography]
#    ------------------------------------ --- 23/25 [unstructured-client]
#    ------------------------------------ --- 23/25 [unstructured-client]
#    ------------------------------------ --- 23/25 [unstructured-client]
#    ------------------------------------ --- 23/25 [unstructured-client]
#    ------------------------------------ --- 23/25 [unstructured-client]
#    ------------------------------------ --- 23/25 [unstructured-client]
#    ------------------------------------ --- 23/25 [unstructured-client]
#    ------------------------------------ --- 23/25 [unstructured-client]
#    ------------------------------------ --- 23/25 [unstructured-client]
#    ------------------------------------ --- 23/25 [unstructured-client]
#    ------------------------------------ --- 23/25 [unstructured-client]
#    ------------------------------------ --- 23/25 [unstructured-client]
#    ------------------------------------ --- 23/25 [unstructured-client]
#    ------------------------------------ --- 23/25 [unstructured-client]
#    ------------------------------------ --- 23/25 [unstructured-client]
#    ------------------------------------ --- 23/25 [unstructured-client]
#    ------------------------------------ --- 23/25 [unstructured-client]
#    ------------------------------------ --- 23/25 [unstructured-client]
#    ------------------------------------ --- 23/25 [unstructured-client]
#    -------------------------------------- - 24/25 [unstructured]
#    -------------------------------------- - 24/25 [unstructured]
#    -------------------------------------- - 24/25 [unstructured]
#    -------------------------------------- - 24/25 [unstructured]
#    -------------------------------------- - 24/25 [unstructured]
#    -------------------------------------- - 24/25 [unstructured]
#    -------------------------------------- - 24/25 [unstructured]
#    -------------------------------------- - 24/25 [unstructured]
#    -------------------------------------- - 24/25 [unstructured]
#    -------------------------------------- - 24/25 [unstructured]
#    -------------------------------------- - 24/25 [unstructured]
#    -------------------------------------- - 24/25 [unstructured]
#    -------------------------------------- - 24/25 [unstructured]
#    -------------------------------------- - 24/25 [unstructured]
#    -------------------------------------- - 24/25 [unstructured]
#    -------------------------------------- - 24/25 [unstructured]
#    -------------------------------------- - 24/25 [unstructured]
#    -------------------------------------- - 24/25 [unstructured]
#    -------------------------------------- - 24/25 [unstructured]
#    -------------------------------------- - 24/25 [unstructured]
#    ---------------------------------------- 25/25 [unstructured]
#
# Successfully installed aiofiles-24.1.0 cffi-1.17.1 chardet-5.2.0 cryptography-45.0.5 defusedxml-0.7.1 emoji-2.14.1 filetype-1.2.0 html5lib-1.1 langdetect-1.0.9 lxml-6.0.0 nltk-3.9.1 numexpr-2.11.0 olefile-0.47 pycparser-2.22 python-iso639-2025.2.18 python-magic-0.4.27 python-oxmsg-0.0.2 pytube-15.0.0 rapidfuzz-3.13.0 unstructured-0.18.3 unstructured-client-0.38.1 validators-0.28.1 webencodings-0.5.1 wrapt-1.17.2 youtube_transcript_api-1.1.1
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: Building 'langdetect' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'langdetect'. Discussion can be found at https://github.com/pypa/pip/issues/6334
